# %% [markdown]
# # Figures

# %% [markdown]
# ### Import Libraries

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
import seaborn as sns
import pandas as pd
import numpy as np

# %%
Accused = pd.read_csv("/Users/sareenah/Desktop/Salem/Accused-Witches-Data-Set.csv")

# %% [markdown]
# ### Clean Data

# %%
# replace NaNs (Not a Number's) with the number zero
Accused['MonthExecution'] = Accused['MonthExecution'].fillna(0)

# %%
# specifying number of bins
num_bins = 5

# %%
#testing num_bins
num_bins
# Out:
# 5

# %%
#loading colour palette
sns.color_palette("Set2", as_cmap=True)

# %% [markdown]
# # The Accused
# The histogram shows bimodal pattern. Two periods of increased activity dropping dramaticly in June, and completely in October.

# %%
sns.displot(data=Accused, x='MonthAccusation', kde=True)# reveals a bimodal non symetric shape

# %% [markdown]
# # Distribution plot
# shows frequency of outbreak is concentrated in 2 main sectors:   Andover, and Salem (Salem Village , and Salem Town)

# %%
sns.displot(data=Accused, x='MonthAccusation', y=' Residence ') # bivariate plot. 
sns.set(rc = {'figure.figsize':(10,5)})

# %% [markdown]
# # The Executed
# Interestingly, the commencement of executions coincide with the drop of new accusations as seen in the earlier histogram.

# %%
sns.displot(data=Accused, x='MonthExecution', kde=True)
sns.set(rc = {'figure.figsize':(10,5)})

# %% [markdown]
# # Pro vs Anti Parris Sentiment

# %% [markdown]
# Tax records list whether the tax payer lodged a ballet either for, or against keeping Rev. Parris on, after the disastrous 15 months of witchysteria.
#
# If taxes are representational of income,
#
# The majority of pro-Parris voters pay double under 200 shilling gs per year in taxes, with three households paying upwards to 400 per year.
# Those with No Side (NoS)

# %%
#import libraries
from matplotlib import pyplot as plt
from matplotlib.axes._axes import _log as matplotlib_axes_logger

matplotlib_axes_logger.setLevel('ERROR')

# Set the figure size - handy for larger output
plt.rcParams["figure.figsize"] = [12, 4]
# %config InlineBackend.figure_format = 'retina' #nicer for the eyes
#load data
TaxData = pd.read_csv(
    '/Users/sareenah/Desktop/Salem/Tax-Comparison-Data-Set.csv',
    header='infer',
    index_col=0,
    squeeze=True).fillna(0)  #replaces any NaNs with 0's
# build graph
TaxData.plot(kind="scatter", x='Petition', y='Sum')
#styling
plt.xticks(horizontalalignment='center', fontweight='bold', fontsize='x-large')
# Out:
# ([0, 1, 2], [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %% [markdown]
# # Parris Sentiment by Voter
# We see an inverse in sentiment by tax payer, compared to sentiment by committee votes.
# NoS pays the least amount of taxes across the board, and Anti-Paris households paying a nose more than Pro-Paris households.

# %%
#build chart
sns.displot(taxData, x="Petition", kde=True)

#styling
plt.xticks(horizontalalignment='center', fontweight='bold', fontsize='x-large')
# Out:
# ([0, 1, 2], [Text(0, 0, 'Pro-P'), Text(1, 0, 'NoS'), Text(2, 0, 'Anti-P')])

# %% [markdown]
# # Accused per Month by Execution
# On average, the accused had to wait 173 days between accusation and execution.

# %%
import matplotlib.pyplot as plt
sns.set_style('darkgrid')
plt.figure(figsize=(10,4))
sns.scatterplot(data=Accused, x='MonthAccusation', y='Sort', hue='MonthExecution')
# Out:
# <AxesSubplot:xlabel='MonthAccusation', ylabel='Sort'>

# %%
plt.figure(figsize=(10,4))
sns.barplot(x ='MonthAccusation', y='Sort', data=Accused)
# Out:
# <AxesSubplot:xlabel='MonthAccusation', ylabel='Sort'>

# %%
plt.figure(figsize=(10,4))
sns.barplot(x ='MonthExecution', y='Sort', data=Accused)
# Out:
# <AxesSubplot:xlabel='MonthExecution', ylabel='Sort'>

# %%
sns.pairplot(Accused)

# %%
sns.displot(Accused, x="MonthAccusation", y="Sort", kind="kde", rug=True)

# %% [markdown]
# # Parris Sentiment by Voter
# The No Side (NoS) votes represent the largest voting block of the Committee members
# Pro-Parris sentiment and Anti-Parris sentiment are very close.

# %%
#loading colour palette
sns.color_palette("Set2", as_cmap=True)

# %%
import pandas as pd

taxData=pd.read_csv('/Users/sareenah/Desktop/Salem/Tax-Comparison-Data-Set.csv', header='infer', index_col=0, squeeze=True).fillna(0)

# %%
#towns.sum(axis=0, skipna=True, level=None, numeric_only=bool, min_count=0)

# %%
# specifying number of bins
num_bins = 3

# %%
num_bins
# Out:
# 3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme(color_codes=True)

# %%
df2 = proP.groupby(['Identification', 'Sex']).size().reset_index(name='count').sort_values('count', ascending=False) 
print (df2)
# Out:
#   Identification Sex  count
# 3    Householder   M     29
# 0  Church-Member   F     27
# 1  Church-Member   M     25
# 2    Householder   F     24

# %%
import pandas as pd

data = pd.read_csv('./Pro-Parris-Social-Data-Set.csv', sep=',')
data
# Out:
#                 Name Identification Sex  Sort
# 0      Wilkins, Jane    Householder   F     1
# 1     Wilkins, Sarah    Householder   F     2
# 2       Fuller, Mary    Householder   F     3
# 3      Wilkins, Ruth    Householder   F     4
# 4     Wilkins, Eliz:    Householder   F     5
# ..               ...            ...  ..   ...
# 100  Holton, Abagail  Church-Member   F   101
# 101     Darlin, Mary  Church-Member   F   102
# 102   Hadlock, Sarah  Church-Member   F   103
# 103    Prince, Sarah  Church-Member   F   104
# 104      Brown, Han:  Church-Member   F   105
#
# [105 rows x 4 columns]

# %% [markdown]
# ## Pro Parris Sentiment

# %%
data = pd.read_csv('./Anti-Parris-Social-Data-Set.csv', sep=',')

# %% [markdown]
# ### Overwhelming support for the Puritan Minister came from male 'outsiders', or non church members.

# %%
plt.figure(figsize=(5, 2))

chart = sns.countplot(data=data[data['Sex'] == 'M'],
                      x='Identification',
                      palette='Set1')

plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='medium'  
)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Young men. 16 years old'),
#   Text(1, 0, 'Householder'),
#   Text(2, 0, '[Church] Member'),
#   Text(3, 0, 'Free-Holder')])

# %% [markdown]
# ### While there is less detail on the female members of the pro-Paris camp,  the trend of non-member support for Parris continues to outstrip member support.

# %%
plt.figure(figsize=(5, 2))

chart = sns.countplot(data=data[data['Sex'] == 'F'],
                      x='Identification',
                      palette='Set1')

plt.xticks(

    horizontalalignment='right',
    fontweight='light',
    fontsize='medium'  
)
# Out:
# (array([0, 1]), [Text(0, 0, '[Church] Member'), Text(1, 0, 'Non-Member')])

# %% [markdown]
# # Anti Paris Sentiment

# %% [markdown]
# ### Male Villagers, Church-Members vs Householders
# Church affiliated males were slightly less likely than non church members to withdraw their support for the minister.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 2))

chart = sns.countplot(data=data[data['Sex'] == 'M'],
                      x='Identification',
                      palette='Set1')

# %% [markdown]
# ### Female Villagers, Church-Members vs Householders
# Among the women, those affiliated with the church were MORE likely to withdraw their support of Paris.

# %%
plt.figure(figsize=(5, 2))

chart = sns.countplot(data=data[data['Sex'] == 'F'],
                      x='Identification',
                      palette='Set1')
